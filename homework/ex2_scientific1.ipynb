# %% [markdown]
# # ex2_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
#
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

print(np.__file__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import matplotlib.pyplot as plt
#       3 from IPython import display # hiển thị rich output
# ----> 5 print(numpy.__file__)
#
# NameError: name 'numpy' is not defined

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.03, 0.99]: 10 samples [[0.21959117 0.28810901 0.18207075 0.91492995 0.3332781  0.20960397
#  0.36741056 0.35079167 0.48262093 0.48851878]]
# + y: len=50, [0.02, 0.99]: 10 samples [[0.89505333 0.1340584  0.24230824 0.10998247 0.11775295 0.33588619
#  0.06362018 0.39371921 0.44558185 0.19022926]]
# + colors: len=50, [0.01, 0.94]: 10 samples [[0.28375631 0.32594624 0.55462827 0.58278333 0.66882624 0.9439836
#  0.8815312  0.28498988 0.57922708 0.39768043]]
# + area: len=50, [0.38, 701.50]: 10 samples [[194.71964055  21.98954381  50.52642627 570.9600395  337.88576452
#  412.09571113 216.33904619   4.213241   146.17563097 591.66287066]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
